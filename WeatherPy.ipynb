# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
count = 0
# list for response results
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_Temp = []
wind_Speed = []
pressure = []

params = { 
  "appid": api_key,
"q": city
}

# %%
for city in cities:
    print("Beginning Data Retrieval")
    print("---------------------------")
    x = requests.get(query_url + city).json()
    # Now x contains list of nested dictionaries 
    # Check the value of "cod" key is equal to 
    # "404", means city is found otherwise, 
    # city is not found 
    if x["cod"] != "404": 
        
        city_name.append(city)
        
        # store the value of "main" 
        # key in variable y 
        y = x["main"] 

        # store the value corresponding 
        # to the "temp" key of y 
        current_temperature = y["temp"] 

        # store the value corresponding 
        # to the "pressure" key of y 
        current_pressure = y["pressure"] 

        # store the value corresponding 
        # to the "humidity" key of y 
        current_humidity = y["humidity"] 
        cloudiness.append(x['clouds']['all'])    
        country.append(x['sys']['country'])
        date.append(time.strftime( '%m-%d-%Y', time.localtime(x['dt'])))
        #date.append(time_converter(x['dt']))
        max_Temp.append(y["temp_max"])
        lat.append(x['coord']['lat'])
        lng.append(x['coord']['lon'])
        humidity.append(y["humidity"])
        wind_Speed.append(x['wind']['speed'])
        pressure.append(y["pressure"])

        # store the value of "weather" 
        # key in variable z 
        z = x["weather"] 

        # store the value corresponding  
        # to the "description" key at  
        # the 0th index of z 
        weather_description = z[0]["description"] 

        # print following values 
        count += 1
        print(f"Processing Record {count} of Set 1| {city}")
         # print following values 
        time.sleep(1)
    else: 
        print(" City Not Found ")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1| nenjiang
# Beginning Data Retrieval
# ---------------------------
# Processing Record 2 of Set 1| venice
# Beginning Data Retrieval
# ---------------------------
# Processing Record 3 of Set 1| cabo san lucas
# Beginning Data Retrieval
# ---------------------------
# Processing Record 4 of Set 1| tiksi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 5 of Set 1| isangel
# Beginning Data Retrieval
# ---------------------------
# Processing Record 6 of Set 1| mataura
# Beginning Data Retrieval
# ---------------------------
# Processing Record 7 of Set 1| esperance
# Beginning Data Retrieval
# ---------------------------
# Processing Record 8 of Set 1| tuktoyaktuk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 9 of Set 1| mahebourg
# Beginning Data Retrieval
# ---------------------------
# Processing Record 10 of Set 1| dutlwe
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 11 of Set 1| nantucket
# Beginning Data Retrieval
# ---------------------------
# Processing Record 12 of Set 1| krasnovishersk
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 13 of Set 1| haines junction
# Beginning Data Retrieval
# ---------------------------
# Processing Record 14 of Set 1| hermanus
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 15 of Set 1| nabire
# Beginning Data Retrieval
# ---------------------------
# Processing Record 16 of Set 1| saldanha
# Beginning Data Retrieval
# ---------------------------
# Processing Record 17 of Set 1| ponta do sol
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 18 of Set 1| bethel
# Beginning Data Retrieval
# ---------------------------
# Processing Record 19 of Set 1| kapaa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 20 of Set 1| thompson
# Beginning Data Retrieval
# ---------------------------
# Processing Record 21 of Set 1| the valley
# Beginning Data Retrieval
# ---------------------------
# Processing Record 22 of Set 1| tomakomai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 23 of Set 1| ushuaia
# Beginning Data Retrieval
# ---------------------------
# Processing Record 24 of Set 1| punta arenas
# Beginning Data Retrieval
# ---------------------------
# Processing Record 25 of Set 1| saskylakh
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 26 of Set 1| pandamatenga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 27 of Set 1| sibu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 28 of Set 1| albany
# Beginning Data Retrieval
# ---------------------------
# Processing Record 29 of Set 1| tasiilaq
# Beginning Data Retrieval
# ---------------------------
# Processing Record 30 of Set 1| agirish
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 31 of Set 1| husavik
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 32 of Set 1| kaitangata
# Beginning Data Retrieval
# ---------------------------
# Processing Record 33 of Set 1| sioux lookout
# Beginning Data Retrieval
# ---------------------------
# Processing Record 34 of Set 1| dali
# Beginning Data Retrieval
# ---------------------------
# Processing Record 35 of Set 1| zapolyarnyy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 36 of Set 1| fortuna
# Beginning Data Retrieval
# ---------------------------
# Processing Record 37 of Set 1| tuatapere
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 38 of Set 1| rikitea
# Beginning Data Retrieval
# ---------------------------
# Processing Record 39 of Set 1| bluff
# Beginning Data Retrieval
# ---------------------------
# Processing Record 40 of Set 1| hobart
# Beginning Data Retrieval
# ---------------------------
# Processing Record 41 of Set 1| vaini
# Beginning Data Retrieval
# ---------------------------
# Processing Record 42 of Set 1| pedernales
# Beginning Data Retrieval
# ---------------------------
# Processing Record 43 of Set 1| beringovskiy
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 44 of Set 1| saint-philippe
# Beginning Data Retrieval
# ---------------------------
# Processing Record 45 of Set 1| mayo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 46 of Set 1| talnakh
# Beginning Data Retrieval
# ---------------------------
# Processing Record 47 of Set 1| waddan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 48 of Set 1| dhidhdhoo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 49 of Set 1| talara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 50 of Set 1| alekseyevsk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 51 of Set 1| rodrigues alves
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 52 of Set 1| torbay
# Beginning Data Retrieval
# ---------------------------
# Processing Record 53 of Set 1| larkana
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 54 of Set 1| lompoc
# Beginning Data Retrieval
# ---------------------------
# Processing Record 55 of Set 1| nangwa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 56 of Set 1| caravelas
# Beginning Data Retrieval
# ---------------------------
# Processing Record 57 of Set 1| palauig
# Beginning Data Retrieval
# ---------------------------
# Processing Record 58 of Set 1| nanortalik
# Beginning Data Retrieval
# ---------------------------
# Processing Record 59 of Set 1| port alfred
# Beginning Data Retrieval
# ---------------------------
# Processing Record 60 of Set 1| puerto baquerizo moreno
# Beginning Data Retrieval
# ---------------------------
# Processing Record 61 of Set 1| isabela
# Beginning Data Retrieval
# ---------------------------
# Processing Record 62 of Set 1| hilo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 63 of Set 1| nivala
# Beginning Data Retrieval
# ---------------------------
# Processing Record 64 of Set 1| ribeira grande
# Beginning Data Retrieval
# ---------------------------
# Processing Record 65 of Set 1| necochea
# Beginning Data Retrieval
# ---------------------------
# Processing Record 66 of Set 1| kindu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 67 of Set 1| cherskiy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 68 of Set 1| mogadishu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 69 of Set 1| khuzhir
# Beginning Data Retrieval
# ---------------------------
# Processing Record 70 of Set 1| georgetown
# Beginning Data Retrieval
# ---------------------------
# Processing Record 71 of Set 1| hamilton
# Beginning Data Retrieval
# ---------------------------
# Processing Record 72 of Set 1| qaanaaq
# Beginning Data Retrieval
# ---------------------------
# Processing Record 73 of Set 1| busselton
# Beginning Data Retrieval
# ---------------------------
# Processing Record 74 of Set 1| puerto ayora
# Beginning Data Retrieval
# ---------------------------
# Processing Record 75 of Set 1| lanigan
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 76 of Set 1| atoyatempan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 77 of Set 1| skoghall
# Beginning Data Retrieval
# ---------------------------
# Processing Record 78 of Set 1| ghanzi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 79 of Set 1| vercheres
# Beginning Data Retrieval
# ---------------------------
# Processing Record 80 of Set 1| zaysan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 81 of Set 1| sidi ali
# Beginning Data Retrieval
# ---------------------------
# Processing Record 82 of Set 1| tsumeb
# Beginning Data Retrieval
# ---------------------------
# Processing Record 83 of Set 1| dashitou
# Beginning Data Retrieval
# ---------------------------
# Processing Record 84 of Set 1| kaeo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 85 of Set 1| mandera
# Beginning Data Retrieval
# ---------------------------
# Processing Record 86 of Set 1| port lincoln
# Beginning Data Retrieval
# ---------------------------
# Processing Record 87 of Set 1| elizabeth city
# Beginning Data Retrieval
# ---------------------------
# Processing Record 88 of Set 1| bereda
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 89 of Set 1| luderitz
# Beginning Data Retrieval
# ---------------------------
# Processing Record 90 of Set 1| lebu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 91 of Set 1| gap
# Beginning Data Retrieval
# ---------------------------
# Processing Record 92 of Set 1| butaritari
# Beginning Data Retrieval
# ---------------------------
# Processing Record 93 of Set 1| mogila
# Beginning Data Retrieval
# ---------------------------
# Processing Record 94 of Set 1| sidrolandia
# Beginning Data Retrieval
# ---------------------------
# Processing Record 95 of Set 1| codrington
# Beginning Data Retrieval
# ---------------------------
# Processing Record 96 of Set 1| norman wells
# Beginning Data Retrieval
# ---------------------------
# Processing Record 97 of Set 1| jamestown
# Beginning Data Retrieval
# ---------------------------
# Processing Record 98 of Set 1| swan hill
# Beginning Data Retrieval
# ---------------------------
# Processing Record 99 of Set 1| juneau
# Beginning Data Retrieval
# ---------------------------
# Processing Record 100 of Set 1| mar del plata
# Beginning Data Retrieval
# ---------------------------
# Processing Record 101 of Set 1| malayal
# Beginning Data Retrieval
# ---------------------------
# Processing Record 102 of Set 1| katsuura
# Beginning Data Retrieval
# ---------------------------
# Processing Record 103 of Set 1| pingliang
# Beginning Data Retrieval
# ---------------------------
# Processing Record 104 of Set 1| victoria
# Beginning Data Retrieval
# ---------------------------
# Processing Record 105 of Set 1| geneva
# Beginning Data Retrieval
# ---------------------------
# Processing Record 106 of Set 1| pevek
# Beginning Data Retrieval
# ---------------------------
# Processing Record 107 of Set 1| severo-kurilsk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 108 of Set 1| launceston
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 109 of Set 1| atuona
# Beginning Data Retrieval
# ---------------------------
# Processing Record 110 of Set 1| san lazaro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 111 of Set 1| yellowknife
# Beginning Data Retrieval
# ---------------------------
# Processing Record 112 of Set 1| cape town
# Beginning Data Retrieval
# ---------------------------
# Processing Record 113 of Set 1| elko
# Beginning Data Retrieval
# ---------------------------
# Processing Record 114 of Set 1| nikolskoye
# Beginning Data Retrieval
# ---------------------------
# Processing Record 115 of Set 1| baruun-urt
# Beginning Data Retrieval
# ---------------------------
# Processing Record 116 of Set 1| kahului
# Beginning Data Retrieval
# ---------------------------
# Processing Record 117 of Set 1| krasnyy chikoy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 118 of Set 1| acoua
# Beginning Data Retrieval
# ---------------------------
# Processing Record 119 of Set 1| road town
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 120 of Set 1| miranda
# Beginning Data Retrieval
# ---------------------------
# Processing Record 121 of Set 1| mandalgovi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 122 of Set 1| palana
# Beginning Data Retrieval
# ---------------------------
# Processing Record 123 of Set 1| mpika
# Beginning Data Retrieval
# ---------------------------
# Processing Record 124 of Set 1| alamogordo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 125 of Set 1| hervey bay
# Beginning Data Retrieval
# ---------------------------
# Processing Record 126 of Set 1| jacareacanga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 127 of Set 1| oistins
# Beginning Data Retrieval
# ---------------------------
# Processing Record 128 of Set 1| barrow
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 129 of Set 1| acari
# Beginning Data Retrieval
# ---------------------------
# Processing Record 130 of Set 1| grindavik
# Beginning Data Retrieval
# ---------------------------
# Processing Record 131 of Set 1| araouane
# Beginning Data Retrieval
# ---------------------------
# Processing Record 132 of Set 1| east london
# Beginning Data Retrieval
# ---------------------------
# Processing Record 133 of Set 1| nouadhibou
# Beginning Data Retrieval
# ---------------------------
# Processing Record 134 of Set 1| lere
# Beginning Data Retrieval
# ---------------------------
# Processing Record 135 of Set 1| lagos
# Beginning Data Retrieval
# ---------------------------
# Processing Record 136 of Set 1| lorengau
# Beginning Data Retrieval
# ---------------------------
# Processing Record 137 of Set 1| viedma
# Beginning Data Retrieval
# ---------------------------
# Processing Record 138 of Set 1| rock sound
# Beginning Data Retrieval
# ---------------------------
# Processing Record 139 of Set 1| flinders
# Beginning Data Retrieval
# ---------------------------
# Processing Record 140 of Set 1| half moon bay
# Beginning Data Retrieval
# ---------------------------
# Processing Record 141 of Set 1| berlevag
# Beginning Data Retrieval
# ---------------------------
# Processing Record 142 of Set 1| atasu
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 143 of Set 1| upernavik
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 144 of Set 1| clyde river
# Beginning Data Retrieval
# ---------------------------
# Processing Record 145 of Set 1| hithadhoo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 146 of Set 1| kodiak
# Beginning Data Retrieval
# ---------------------------
# Processing Record 147 of Set 1| vanimo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 148 of Set 1| icatu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 149 of Set 1| kruisfontein
# Beginning Data Retrieval
# ---------------------------
# Processing Record 150 of Set 1| lata
# Beginning Data Retrieval
# ---------------------------
# Processing Record 151 of Set 1| guerrero negro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 152 of Set 1| luena
# Beginning Data Retrieval
# ---------------------------
# Processing Record 153 of Set 1| bambous virieux
# Beginning Data Retrieval
# ---------------------------
# Processing Record 154 of Set 1| pinega
# Beginning Data Retrieval
# ---------------------------
# Processing Record 155 of Set 1| hasaki
# Beginning Data Retrieval
# ---------------------------
# Processing Record 156 of Set 1| chokurdakh
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 157 of Set 1| sitka
# Beginning Data Retrieval
# ---------------------------
# Processing Record 158 of Set 1| saint george
# Beginning Data Retrieval
# ---------------------------
# Processing Record 159 of Set 1| abnub
# Beginning Data Retrieval
# ---------------------------
# Processing Record 160 of Set 1| zverinogolovskoye
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 161 of Set 1| makakilo city
# Beginning Data Retrieval
# ---------------------------
# Processing Record 162 of Set 1| kalangala
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 163 of Set 1| nome
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 164 of Set 1| saint-pierre
# Beginning Data Retrieval
# ---------------------------
# Processing Record 165 of Set 1| sao filipe
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 166 of Set 1| vila franca do campo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 167 of Set 1| shizunai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 168 of Set 1| northam
# Beginning Data Retrieval
# ---------------------------
# Processing Record 169 of Set 1| vestmannaeyjar
# Beginning Data Retrieval
# ---------------------------
# Processing Record 170 of Set 1| bargur
# Beginning Data Retrieval
# ---------------------------
# Processing Record 171 of Set 1| narsaq
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 172 of Set 1| bilma
# Beginning Data Retrieval
# ---------------------------
# Processing Record 173 of Set 1| broome
# Beginning Data Retrieval
# ---------------------------
# Processing Record 174 of Set 1| pacific grove
# Beginning Data Retrieval
# ---------------------------
# Processing Record 175 of Set 1| katherine
# Beginning Data Retrieval
# ---------------------------
# Processing Record 176 of Set 1| kabalo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 177 of Set 1| gusau
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 178 of Set 1| gotsu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 179 of Set 1| murgab
# Beginning Data Retrieval
# ---------------------------
# Processing Record 180 of Set 1| sinnamary
# Beginning Data Retrieval
# ---------------------------
# Processing Record 181 of Set 1| muros
# Beginning Data Retrieval
# ---------------------------
# Processing Record 182 of Set 1| casablanca
# Beginning Data Retrieval
# ---------------------------
# Processing Record 183 of Set 1| omboue
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 184 of Set 1| bredasdorp
# Beginning Data Retrieval
# ---------------------------
# Processing Record 185 of Set 1| huarmey
# Beginning Data Retrieval
# ---------------------------
# Processing Record 186 of Set 1| moerai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 187 of Set 1| eureka
# Beginning Data Retrieval
# ---------------------------
# Processing Record 188 of Set 1| rawson
# Beginning Data Retrieval
# ---------------------------
# Processing Record 189 of Set 1| uruzgan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 190 of Set 1| cocobeach
# Beginning Data Retrieval
# ---------------------------
# Processing Record 191 of Set 1| prince rupert
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 192 of Set 1| airai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 193 of Set 1| ambalavao
# Beginning Data Retrieval
# ---------------------------
# Processing Record 194 of Set 1| iqaluit
# Beginning Data Retrieval
# ---------------------------
# Processing Record 195 of Set 1| gondanglegi
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 196 of Set 1| biak
# Beginning Data Retrieval
# ---------------------------
# Processing Record 197 of Set 1| hooglede
# Beginning Data Retrieval
# ---------------------------
# Processing Record 198 of Set 1| kaoma
# Beginning Data Retrieval
# ---------------------------
# Processing Record 199 of Set 1| mixco
# Beginning Data Retrieval
# ---------------------------
# Processing Record 200 of Set 1| saint anthony
# Beginning Data Retrieval
# ---------------------------
# Processing Record 201 of Set 1| pochutla
# Beginning Data Retrieval
# ---------------------------
# Processing Record 202 of Set 1| katangli
# Beginning Data Retrieval
# ---------------------------
# Processing Record 203 of Set 1| camacha
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 204 of Set 1| iquique
# Beginning Data Retrieval
# ---------------------------
# Processing Record 205 of Set 1| alice springs
# Beginning Data Retrieval
# ---------------------------
# Processing Record 206 of Set 1| namibe
# Beginning Data Retrieval
# ---------------------------
# Processing Record 207 of Set 1| mount gambier
# Beginning Data Retrieval
# ---------------------------
# Processing Record 208 of Set 1| willowmore
# Beginning Data Retrieval
# ---------------------------
# Processing Record 209 of Set 1| souillac
# Beginning Data Retrieval
# ---------------------------
# Processing Record 210 of Set 1| maniitsoq
# Beginning Data Retrieval
# ---------------------------
# Processing Record 211 of Set 1| sovetskaya gavan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 212 of Set 1| santa isabel do rio negro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 213 of Set 1| maragogi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 214 of Set 1| winnemucca
# Beginning Data Retrieval
# ---------------------------
# Processing Record 215 of Set 1| kapit
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 216 of Set 1| adrar
# Beginning Data Retrieval
# ---------------------------
# Processing Record 217 of Set 1| southbridge
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 218 of Set 1| provideniya
# Beginning Data Retrieval
# ---------------------------
# Processing Record 219 of Set 1| new norfolk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 220 of Set 1| vanavara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 221 of Set 1| muravlenko
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 222 of Set 1| itarema
# Beginning Data Retrieval
# ---------------------------
# Processing Record 223 of Set 1| port macquarie
# Beginning Data Retrieval
# ---------------------------
# Processing Record 224 of Set 1| itapaci
# Beginning Data Retrieval
# ---------------------------
# Processing Record 225 of Set 1| kuytun
# Beginning Data Retrieval
# ---------------------------
# Processing Record 226 of Set 1| ixtapa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 227 of Set 1| ilulissat
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 228 of Set 1| mahibadhoo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 229 of Set 1| arraial do cabo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 230 of Set 1| clarksdale
# Beginning Data Retrieval
# ---------------------------
# Processing Record 231 of Set 1| san patricio
# Beginning Data Retrieval
# ---------------------------
# Processing Record 232 of Set 1| sedalia
# Beginning Data Retrieval
# ---------------------------
# Processing Record 233 of Set 1| bom jesus
# Beginning Data Retrieval
# ---------------------------
# Processing Record 234 of Set 1| dikson
# Beginning Data Retrieval
# ---------------------------
# Processing Record 235 of Set 1| honningsvag
# Beginning Data Retrieval
# ---------------------------
# Processing Record 236 of Set 1| lubao
# Beginning Data Retrieval
# ---------------------------
# Processing Record 237 of Set 1| ucluelet
# Beginning Data Retrieval
# ---------------------------
# Processing Record 238 of Set 1| saint-augustin
# Beginning Data Retrieval
# ---------------------------
# Processing Record 239 of Set 1| bandundu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 240 of Set 1| port elizabeth
# Beginning Data Retrieval
# ---------------------------
# Processing Record 241 of Set 1| yulara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 242 of Set 1| sabha
# Beginning Data Retrieval
# ---------------------------
# Processing Record 243 of Set 1| carnarvon
# Beginning Data Retrieval
# ---------------------------
# Processing Record 244 of Set 1| praia
# Beginning Data Retrieval
# ---------------------------
# Processing Record 245 of Set 1| muroto
# Beginning Data Retrieval
# ---------------------------
# Processing Record 246 of Set 1| mongoumba
# Beginning Data Retrieval
# ---------------------------
# Processing Record 247 of Set 1| atherton
# Beginning Data Retrieval
# ---------------------------
# Processing Record 248 of Set 1| mankera
# Beginning Data Retrieval
# ---------------------------
# Processing Record 249 of Set 1| saint-georges
# Beginning Data Retrieval
# ---------------------------
# Processing Record 250 of Set 1| pangnirtung
# Beginning Data Retrieval
# ---------------------------
# Processing Record 251 of Set 1| huancavelica
# Beginning Data Retrieval
# ---------------------------
# Processing Record 252 of Set 1| meulaboh
# Beginning Data Retrieval
# ---------------------------
# Processing Record 253 of Set 1| anadyr
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 254 of Set 1| sosva
# Beginning Data Retrieval
# ---------------------------
# Processing Record 255 of Set 1| sivas
# Beginning Data Retrieval
# ---------------------------
# Processing Record 256 of Set 1| ola
# Beginning Data Retrieval
# ---------------------------
# Processing Record 257 of Set 1| brae
# Beginning Data Retrieval
# ---------------------------
# Processing Record 258 of Set 1| colares
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 259 of Set 1| cayenne
# Beginning Data Retrieval
# ---------------------------
# Processing Record 260 of Set 1| paragominas
# Beginning Data Retrieval
# ---------------------------
# Processing Record 261 of Set 1| khatanga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 262 of Set 1| grand-santi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 263 of Set 1| shubarkuduk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 264 of Set 1| ankpa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 265 of Set 1| conde
# Beginning Data Retrieval
# ---------------------------
# Processing Record 266 of Set 1| castro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 267 of Set 1| bosaso
# Beginning Data Retrieval
# ---------------------------
# Processing Record 268 of Set 1| los llanos de aridane
# Beginning Data Retrieval
# ---------------------------
# Processing Record 269 of Set 1| linxia
# Beginning Data Retrieval
# ---------------------------
# Processing Record 270 of Set 1| emborion
# Beginning Data Retrieval
# ---------------------------
# Processing Record 271 of Set 1| hambantota
# Beginning Data Retrieval
# ---------------------------
# Processing Record 272 of Set 1| chernyshevskiy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 273 of Set 1| ostrovnoy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 274 of Set 1| smoky lake
# Beginning Data Retrieval
# ---------------------------
# Processing Record 275 of Set 1| samarai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 276 of Set 1| sorong
# Beginning Data Retrieval
# ---------------------------
# Processing Record 277 of Set 1| kingston
# Beginning Data Retrieval
# ---------------------------
# Processing Record 278 of Set 1| cidreira
# Beginning Data Retrieval
# ---------------------------
# Processing Record 279 of Set 1| margate
# Beginning Data Retrieval
# ---------------------------
# Processing Record 280 of Set 1| songea
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 281 of Set 1| moree
# Beginning Data Retrieval
# ---------------------------
# Processing Record 282 of Set 1| anloga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 283 of Set 1| ugoofaaru
# Beginning Data Retrieval
# ---------------------------
# Processing Record 284 of Set 1| miraflores
# Beginning Data Retrieval
# ---------------------------
# Processing Record 285 of Set 1| leh
# Beginning Data Retrieval
# ---------------------------
# Processing Record 286 of Set 1| sapa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 287 of Set 1| chuy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 288 of Set 1| palmer
# Beginning Data Retrieval
# ---------------------------
# Processing Record 289 of Set 1| avarua
# Beginning Data Retrieval
# ---------------------------
# Processing Record 290 of Set 1| almaznyy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 291 of Set 1| bonavista
# Beginning Data Retrieval
# ---------------------------
# Processing Record 292 of Set 1| sulangan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 293 of Set 1| la rinconada
# Beginning Data Retrieval
# ---------------------------
# Processing Record 294 of Set 1| shenjiamen
# Beginning Data Retrieval
# ---------------------------
# Processing Record 295 of Set 1| ayan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 296 of Set 1| enderby
# Beginning Data Retrieval
# ---------------------------
# Processing Record 297 of Set 1| san cristobal
# Beginning Data Retrieval
# ---------------------------
# Processing Record 298 of Set 1| banjar
# Beginning Data Retrieval
# ---------------------------
# Processing Record 299 of Set 1| karratha
# Beginning Data Retrieval
# ---------------------------
# Processing Record 300 of Set 1| avera
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 301 of Set 1| pacifica
# Beginning Data Retrieval
# ---------------------------
# Processing Record 302 of Set 1| yarmouth
# Beginning Data Retrieval
# ---------------------------
# Processing Record 303 of Set 1| kahta
# Beginning Data Retrieval
# ---------------------------
# Processing Record 304 of Set 1| fukue
# Beginning Data Retrieval
# ---------------------------
# Processing Record 305 of Set 1| tevriz
# Beginning Data Retrieval
# ---------------------------
# Processing Record 306 of Set 1| ahmadpur
# Beginning Data Retrieval
# ---------------------------
# Processing Record 307 of Set 1| srednekolymsk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 308 of Set 1| roald
# Beginning Data Retrieval
# ---------------------------
# Processing Record 309 of Set 1| ashtian
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 310 of Set 1| ruston
# Beginning Data Retrieval
# ---------------------------
# Processing Record 311 of Set 1| troitskoye
# Beginning Data Retrieval
# ---------------------------
# Processing Record 312 of Set 1| tulun
# Beginning Data Retrieval
# ---------------------------
# Processing Record 313 of Set 1| zhezkazgan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 314 of Set 1| zorritos
# Beginning Data Retrieval
# ---------------------------
# Processing Record 315 of Set 1| geraldton
# Beginning Data Retrieval
# ---------------------------
# Processing Record 316 of Set 1| ormara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 317 of Set 1| bandarbeyla
# Beginning Data Retrieval
# ---------------------------
# Processing Record 318 of Set 1| coruripe
# Beginning Data Retrieval
# ---------------------------
# Processing Record 319 of Set 1| ozark
# Beginning Data Retrieval
# ---------------------------
# Processing Record 320 of Set 1| gizo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 321 of Set 1| nioro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 322 of Set 1| mnogovershinnyy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 323 of Set 1| tual
# Beginning Data Retrieval
# ---------------------------
# Processing Record 324 of Set 1| egvekinot
# Beginning Data Retrieval
# ---------------------------
# Processing Record 325 of Set 1| wamba
# Beginning Data Retrieval
# ---------------------------
# Processing Record 326 of Set 1| nemuro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 327 of Set 1| coquimbo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 328 of Set 1| granard
# Beginning Data Retrieval
# ---------------------------
# Processing Record 329 of Set 1| kuito
# Beginning Data Retrieval
# ---------------------------
# Processing Record 330 of Set 1| port blair
# Beginning Data Retrieval
# ---------------------------
# Processing Record 331 of Set 1| polis
# Beginning Data Retrieval
# ---------------------------
# Processing Record 332 of Set 1| sibolga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 333 of Set 1| millinocket
# Beginning Data Retrieval
# ---------------------------
# Processing Record 334 of Set 1| mastic beach
# Beginning Data Retrieval
# ---------------------------
# Processing Record 335 of Set 1| ortakoy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 336 of Set 1| boca do acre
# Beginning Data Retrieval
# ---------------------------
# Processing Record 337 of Set 1| jasidih
# Beginning Data Retrieval
# ---------------------------
# Processing Record 338 of Set 1| yumen
# Beginning Data Retrieval
# ---------------------------
# Processing Record 339 of Set 1| turukhansk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 340 of Set 1| lebedinyy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 341 of Set 1| gigmoto
# Beginning Data Retrieval
# ---------------------------
# Processing Record 342 of Set 1| orahovac
# Beginning Data Retrieval
# ---------------------------
# Processing Record 343 of Set 1| vrangel
# Beginning Data Retrieval
# ---------------------------
# Processing Record 344 of Set 1| tiarei
# Beginning Data Retrieval
# ---------------------------
# Processing Record 345 of Set 1| ettaiyapuram
# Beginning Data Retrieval
# ---------------------------
# Processing Record 346 of Set 1| bukama
# Beginning Data Retrieval
# ---------------------------
# Processing Record 347 of Set 1| medea
# Beginning Data Retrieval
# ---------------------------
# Processing Record 348 of Set 1| godda
# Beginning Data Retrieval
# ---------------------------
# Processing Record 349 of Set 1| coihaique
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 350 of Set 1| padang
# Beginning Data Retrieval
# ---------------------------
# Processing Record 351 of Set 1| loukhi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 352 of Set 1| gopalpur
# Beginning Data Retrieval
# ---------------------------
# Processing Record 353 of Set 1| noumea
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 354 of Set 1| lancaster
# Beginning Data Retrieval
# ---------------------------
# Processing Record 355 of Set 1| kalabo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 356 of Set 1| virginia beach
# Beginning Data Retrieval
# ---------------------------
# Processing Record 357 of Set 1| qaqortoq
# Beginning Data Retrieval
# ---------------------------
# Processing Record 358 of Set 1| plettenberg bay
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 359 of Set 1| namatanai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 360 of Set 1| riyadh
# Beginning Data Retrieval
# ---------------------------
# Processing Record 361 of Set 1| aklavik
# Beginning Data Retrieval
# ---------------------------
# Processing Record 362 of Set 1| saravan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 363 of Set 1| athabasca
# Beginning Data Retrieval
# ---------------------------
# Processing Record 364 of Set 1| nishihara
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 365 of Set 1| roma
# Beginning Data Retrieval
# ---------------------------
# Processing Record 366 of Set 1| paola
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 367 of Set 1| forbes
# Beginning Data Retrieval
# ---------------------------
# Processing Record 368 of Set 1| ahipara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 369 of Set 1| longyearbyen
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 370 of Set 1| puerto del rosario
# Beginning Data Retrieval
# ---------------------------
# Processing Record 371 of Set 1| takestan
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 372 of Set 1| port keats
# Beginning Data Retrieval
# ---------------------------
# Processing Record 373 of Set 1| valledupar
# Beginning Data Retrieval
# ---------------------------
# Processing Record 374 of Set 1| kirove
# Beginning Data Retrieval
# ---------------------------
# Processing Record 375 of Set 1| aquiraz
# Beginning Data Retrieval
# ---------------------------
# Processing Record 376 of Set 1| dukuhturi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 377 of Set 1| constitucion
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 378 of Set 1| ambilobe
# Beginning Data Retrieval
# ---------------------------
# Processing Record 379 of Set 1| vardo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 380 of Set 1| faanui
# Beginning Data Retrieval
# ---------------------------
# Processing Record 381 of Set 1| morant bay
# Beginning Data Retrieval
# ---------------------------
# Processing Record 382 of Set 1| baghdad
# Beginning Data Retrieval
# ---------------------------
# Processing Record 383 of Set 1| pucallpa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 384 of Set 1| fenoarivo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 385 of Set 1| papagaios
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 386 of Set 1| tocopilla
# Beginning Data Retrieval
# ---------------------------
# Processing Record 387 of Set 1| poya
# Beginning Data Retrieval
# ---------------------------
# Processing Record 388 of Set 1| abu samrah
# Beginning Data Retrieval
# ---------------------------
# Processing Record 389 of Set 1| cairns
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 390 of Set 1| yurty
# Beginning Data Retrieval
# ---------------------------
# Processing Record 391 of Set 1| boden
# Beginning Data Retrieval
# ---------------------------
# Processing Record 392 of Set 1| hirara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 393 of Set 1| lewiston
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 394 of Set 1| ocotepec
# Beginning Data Retrieval
# ---------------------------
# Processing Record 395 of Set 1| hofn
# Beginning Data Retrieval
# ---------------------------
# Processing Record 396 of Set 1| acapulco
# Beginning Data Retrieval
# ---------------------------
# Processing Record 397 of Set 1| waingapu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 398 of Set 1| koungheul
# Beginning Data Retrieval
# ---------------------------
# Processing Record 399 of Set 1| tokur
# Beginning Data Retrieval
# ---------------------------
# Processing Record 400 of Set 1| wasserburg
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 401 of Set 1| kutulik
# Beginning Data Retrieval
# ---------------------------
# Processing Record 402 of Set 1| aberdeen
# Beginning Data Retrieval
# ---------------------------
# Processing Record 403 of Set 1| west wendover
# Beginning Data Retrieval
# ---------------------------
# Processing Record 404 of Set 1| bambanglipuro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 405 of Set 1| babynino
# Beginning Data Retrieval
# ---------------------------
# Processing Record 406 of Set 1| swift current
# Beginning Data Retrieval
# ---------------------------
# Processing Record 407 of Set 1| tigil
# Beginning Data Retrieval
# ---------------------------
# Processing Record 408 of Set 1| merauke
# Beginning Data Retrieval
# ---------------------------
# Processing Record 409 of Set 1| jurilovca
# Beginning Data Retrieval
# ---------------------------
# Processing Record 410 of Set 1| labuhan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 411 of Set 1| lubumbashi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 412 of Set 1| mehamn
# Beginning Data Retrieval
# ---------------------------
# Processing Record 413 of Set 1| podbrdo
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 414 of Set 1| arlit
# Beginning Data Retrieval
# ---------------------------
# Processing Record 415 of Set 1| seoul
# Beginning Data Retrieval
# ---------------------------
# Processing Record 416 of Set 1| darnah
# Beginning Data Retrieval
# ---------------------------
# Processing Record 417 of Set 1| raduzhnyy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 418 of Set 1| kavieng
# Beginning Data Retrieval
# ---------------------------
# Processing Record 419 of Set 1| maroantsetra
# Beginning Data Retrieval
# ---------------------------
# Processing Record 420 of Set 1| kabansk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 421 of Set 1| buala
# Beginning Data Retrieval
# ---------------------------
# Processing Record 422 of Set 1| wronki
# Beginning Data Retrieval
# ---------------------------
# Processing Record 423 of Set 1| kholtoson
# Beginning Data Retrieval
# ---------------------------
# Processing Record 424 of Set 1| san quintin
# Beginning Data Retrieval
# ---------------------------
# Processing Record 425 of Set 1| ouadda
# Beginning Data Retrieval
# ---------------------------
# Processing Record 426 of Set 1| petatlan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 427 of Set 1| freetown
# Beginning Data Retrieval
# ---------------------------
# Processing Record 428 of Set 1| ribeirao branco
# Beginning Data Retrieval
# ---------------------------
# Processing Record 429 of Set 1| kiunga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 430 of Set 1| san ramon
# Beginning Data Retrieval
# ---------------------------
# Processing Record 431 of Set 1| phulabani
# Beginning Data Retrieval
# ---------------------------
# Processing Record 432 of Set 1| wewak
# Beginning Data Retrieval
# ---------------------------
# Processing Record 433 of Set 1| singkang
# Beginning Data Retrieval
# ---------------------------
# Processing Record 434 of Set 1| sherlovaya gora
# Beginning Data Retrieval
# ---------------------------
# Processing Record 435 of Set 1| luba
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 436 of Set 1| charters towers
# Beginning Data Retrieval
# ---------------------------
# Processing Record 437 of Set 1| ovalle
# Beginning Data Retrieval
# ---------------------------
# Processing Record 438 of Set 1| centenario do sul
# Beginning Data Retrieval
# ---------------------------
# Processing Record 439 of Set 1| yar-sale
# Beginning Data Retrieval
# ---------------------------
# Processing Record 440 of Set 1| grenada
# Beginning Data Retrieval
# ---------------------------
# Processing Record 441 of Set 1| komsomolskiy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 442 of Set 1| perpignan
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 443 of Set 1| onokhoy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 444 of Set 1| moron
# Beginning Data Retrieval
# ---------------------------
# Processing Record 445 of Set 1| nhulunbuy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 446 of Set 1| agrafa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 447 of Set 1| gujranwala
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 448 of Set 1| zavetnyy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 449 of Set 1| ketchikan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 450 of Set 1| itabira
# Beginning Data Retrieval
# ---------------------------
# Processing Record 451 of Set 1| antofagasta
# Beginning Data Retrieval
# ---------------------------
# Processing Record 452 of Set 1| nador
# Beginning Data Retrieval
# ---------------------------
# Processing Record 453 of Set 1| auki
# Beginning Data Retrieval
# ---------------------------
# Processing Record 454 of Set 1| dera bugti
# Beginning Data Retrieval
# ---------------------------
# Processing Record 455 of Set 1| keroka
# Beginning Data Retrieval
# ---------------------------
# Processing Record 456 of Set 1| ginir
# Beginning Data Retrieval
# ---------------------------
# Processing Record 457 of Set 1| kalmunai
# Beginning Data Retrieval
# ---------------------------
# Processing Record 458 of Set 1| mabaruma
# Beginning Data Retrieval
# ---------------------------
# Processing Record 459 of Set 1| santa maria
# Beginning Data Retrieval
# ---------------------------
# Processing Record 460 of Set 1| shimoda
# Beginning Data Retrieval
# ---------------------------
# Processing Record 461 of Set 1| annau
# Beginning Data Retrieval
# ---------------------------
# Processing Record 462 of Set 1| douglas
# Beginning Data Retrieval
# ---------------------------
# Processing Record 463 of Set 1| zhigansk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 464 of Set 1| naze
# Beginning Data Retrieval
# ---------------------------
# Processing Record 465 of Set 1| merrill
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 466 of Set 1| malinyi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 467 of Set 1| laguna
# Beginning Data Retrieval
# ---------------------------
# Processing Record 468 of Set 1| puerto escondido
# Beginning Data Retrieval
# ---------------------------
# Processing Record 469 of Set 1| coria
# Beginning Data Retrieval
# ---------------------------
# Processing Record 470 of Set 1| moose factory
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 471 of Set 1| jinzhou
# Beginning Data Retrieval
# ---------------------------
# Processing Record 472 of Set 1| mumford
# Beginning Data Retrieval
# ---------------------------
# Processing Record 473 of Set 1| abengourou
# Beginning Data Retrieval
# ---------------------------
# Processing Record 474 of Set 1| axim
# Beginning Data Retrieval
# ---------------------------
# Processing Record 475 of Set 1| vasarosnameny
# Beginning Data Retrieval
# ---------------------------
# Processing Record 476 of Set 1| lerwick
# Beginning Data Retrieval
# ---------------------------
# Processing Record 477 of Set 1| paita
# Beginning Data Retrieval
# ---------------------------
# Processing Record 478 of Set 1| rio brilhante
# Beginning Data Retrieval
# ---------------------------
# Processing Record 479 of Set 1| mount isa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 480 of Set 1| pahrump
# Beginning Data Retrieval
# ---------------------------
# Processing Record 481 of Set 1| pisco
# Beginning Data Retrieval
# ---------------------------
# Processing Record 482 of Set 1| balabac
# Beginning Data Retrieval
# ---------------------------
# Processing Record 483 of Set 1| lexington
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 484 of Set 1| atambua
# Beginning Data Retrieval
# ---------------------------
# Processing Record 485 of Set 1| hihya
# Beginning Data Retrieval
# ---------------------------
# Processing Record 486 of Set 1| ponta delgada
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 487 of Set 1| omsukchan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 488 of Set 1| mitu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 489 of Set 1| buchanan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 490 of Set 1| salalah
# Beginning Data Retrieval
# ---------------------------
# Processing Record 491 of Set 1| mackay
# Beginning Data Retrieval
# ---------------------------
# Processing Record 492 of Set 1| deputatskiy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 493 of Set 1| manta
# Beginning Data Retrieval
# ---------------------------
# Processing Record 494 of Set 1| lakatoro
# Beginning Data Retrieval
# ---------------------------
# Processing Record 495 of Set 1| matamoros
# Beginning Data Retrieval
# ---------------------------
# Processing Record 496 of Set 1| grand gaube
# Beginning Data Retrieval
# ---------------------------
# Processing Record 497 of Set 1| dodola
# Beginning Data Retrieval
# ---------------------------
# Processing Record 498 of Set 1| tramore
# Beginning Data Retrieval
# ---------------------------
# Processing Record 499 of Set 1| mariental
# Beginning Data Retrieval
# ---------------------------
# Processing Record 500 of Set 1| anshun
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 501 of Set 1| shubarshi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 502 of Set 1| vaitape
# Beginning Data Retrieval
# ---------------------------
# Processing Record 503 of Set 1| okhotsk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 504 of Set 1| luwuk
# Beginning Data Retrieval
# ---------------------------
# Processing Record 505 of Set 1| tautira
# Beginning Data Retrieval
# ---------------------------
# Processing Record 506 of Set 1| chingirlau
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 507 of Set 1| igarka
# Beginning Data Retrieval
# ---------------------------
# Processing Record 508 of Set 1| ust-kuyga
# Beginning Data Retrieval
# ---------------------------
# Processing Record 509 of Set 1| palu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 510 of Set 1| kropotkin
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 511 of Set 1| basco
# Beginning Data Retrieval
# ---------------------------
# Processing Record 512 of Set 1| luan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 513 of Set 1| jasper
# Beginning Data Retrieval
# ---------------------------
# Processing Record 514 of Set 1| ialibu
# Beginning Data Retrieval
# ---------------------------
# Processing Record 515 of Set 1| jizan
# Beginning Data Retrieval
# ---------------------------
# Processing Record 516 of Set 1| havoysund
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 517 of Set 1| kimberley
# Beginning Data Retrieval
# ---------------------------
# Processing Record 518 of Set 1| divo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 519 of Set 1| filadelfia
# Beginning Data Retrieval
# ---------------------------
# Processing Record 520 of Set 1| trairi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 521 of Set 1| birin
# Beginning Data Retrieval
# ---------------------------
# Processing Record 522 of Set 1| buraydah
# Beginning Data Retrieval
# ---------------------------
# Processing Record 523 of Set 1| stephenville
# Beginning Data Retrieval
# ---------------------------
# Processing Record 524 of Set 1| tessalit
# Beginning Data Retrieval
# ---------------------------
# Processing Record 525 of Set 1| havelock
# Beginning Data Retrieval
# ---------------------------
# Processing Record 526 of Set 1| chateauroux
# Beginning Data Retrieval
# ---------------------------
# Processing Record 527 of Set 1| moindou
# Beginning Data Retrieval
# ---------------------------
# Processing Record 528 of Set 1| damara
# Beginning Data Retrieval
# ---------------------------
# Processing Record 529 of Set 1| sarny
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 530 of Set 1| imbituba
# Beginning Data Retrieval
# ---------------------------
# Processing Record 531 of Set 1| maldonado
# Beginning Data Retrieval
# ---------------------------
# Processing Record 532 of Set 1| nurota
# Beginning Data Retrieval
# ---------------------------
# Processing Record 533 of Set 1| kaniama
# Beginning Data Retrieval
# ---------------------------
# Processing Record 534 of Set 1| tommot
# Beginning Data Retrieval
# ---------------------------
# Processing Record 535 of Set 1| poniatowa
# Beginning Data Retrieval
# ---------------------------
# Processing Record 536 of Set 1| port hedland
# Beginning Data Retrieval
# ---------------------------
# Processing Record 537 of Set 1| najran
# Beginning Data Retrieval
# ---------------------------
# Processing Record 538 of Set 1| sao joao da barra
# Beginning Data Retrieval
# ---------------------------
# Processing Record 539 of Set 1| petropavlovsk-kamchatskiy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 540 of Set 1| hami
# Beginning Data Retrieval
# ---------------------------
#  City Not Found
# Beginning Data Retrieval
# ---------------------------
# Processing Record 541 of Set 1| soyo
# Beginning Data Retrieval
# ---------------------------
# Processing Record 542 of Set 1| panzhihua
# Beginning Data Retrieval
# ---------------------------
# Processing Record 543 of Set 1| loikaw
# Beginning Data Retrieval
# ---------------------------
# Processing Record 544 of Set 1| vestmanna
# Beginning Data Retrieval
# ---------------------------
# Processing Record 545 of Set 1| oktyabrskiy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 546 of Set 1| bodden town
# Beginning Data Retrieval
# ---------------------------
# Processing Record 547 of Set 1| biograd na moru
# Beginning Data Retrieval
# ---------------------------
# Processing Record 548 of Set 1| kalghatgi
# Beginning Data Retrieval
# ---------------------------
# Processing Record 549 of Set 1| borogontsy
# Beginning Data Retrieval
# ---------------------------
# Processing Record 550 of Set 1| sindor
# Beginning Data Retrieval
# ---------------------------
# Processing Record 551 of Set 1| vao
# Beginning Data Retrieval
# ---------------------------
# Processing Record 552 of Set 1| portland
# Beginning Data Retrieval
# ---------------------------
# Processing Record 553 of Set 1| cap malheureux

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city": city_name,
    "cloudiness":cloudiness,
    "country": country,    
    "date":date,
    "humidity":humidity,
    "lat":lat,
    "lng":lng,
    "max_Temp":max_Temp,
    "wind_Speed":wind_Speed
}
weather_dict

weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#              city  cloudiness country        date  humidity    lat     lng  \
# 0        nenjiang           0      CN  09-01-2019        78  49.17  125.23
# 1          venice          75      US  09-01-2019        59  27.10  -82.45
# 2  cabo san lucas          75      MX  09-01-2019        66  22.89 -109.91
# 3           tiksi         100      RU  09-01-2019        84  71.64  128.87
# 4         isangel         100      VU  09-01-2019        86 -19.55  169.27
#
#    max_Temp  wind_Speed
# 0     10.15        2.36
# 1     34.44        4.60
# 2     33.33        3.60
# 3      3.95        2.36
# 4     23.85       10.41

# %%
export_csv = weather_data.to_csv (r'.\export_dataframe.csv', index = None, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["max_Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature  ("+ date[0] + ")")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity  ("+ date[0] + ")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness  ("+ date[0] + ")" )
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["wind_Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed  ("+ date[0] + ")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind SpeedInWorldCities.png")

# Show plot
plt.show()
